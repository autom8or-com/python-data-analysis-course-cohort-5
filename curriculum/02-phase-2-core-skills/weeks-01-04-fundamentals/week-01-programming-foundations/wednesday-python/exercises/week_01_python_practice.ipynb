# %% [markdown]
# # Week 01 Python Practice Exercises
#
# **Due**: Before Thursday's SQL Session
# **Instructions**: Complete all exercises and add your reflection at the end
#
# ---
#
# ## Exercise 1: Variables and Data Types (20 points)
#
# **Scenario**: You're setting up customer profiles for a new Nigerian e-commerce platform.
#
# ### Task 1.1: Create Customer Variables

# %%
# Create variables for a Nigerian customer
# Fill in realistic values for each variable

customer_name = "______"           # String: Full name
customer_age = ______              # Integer: Age in years  
customer_city = "______"           # String: Nigerian city
monthly_income = ______            # Float: Income in Naira
has_smartphone = ______            # Boolean: True or False
years_online_shopping = ______     # Integer: Years of experience

# Display customer profile
print("=== CUSTOMER PROFILE ===")
print(f"Name: {customer_name}")
print(f"Age: {customer_age} years old")
print(f"Location: {customer_city}")
print(f"Monthly Income: ₦{monthly_income:,}")
print(f"Smartphone User: {has_smartphone}")
print(f"Online Shopping Experience: {years_online_shopping} years")

# %% [markdown]
# ### Task 1.2: Business Calculations

# %%
# Calculate customer spending potential and category
# Use the variables from Task 1.1

# Calculate estimated monthly e-commerce budget (5% of income)
estimated_monthly_budget = monthly_income * 0.05

# Calculate annual shopping potential
annual_potential = estimated_monthly_budget * 12

# Determine customer category based on income
if monthly_income >= 500000:
    customer_tier = "Premium"
elif monthly_income >= 200000:
    customer_tier = "Gold"
elif monthly_income >= 100000:
    customer_tier = "Silver"
else:
    customer_tier = "Bronze"

# Determine marketing priority
high_priority = has_smartphone and years_online_shopping >= 2 and monthly_income >= 150000

print("=== BUSINESS ANALYSIS ===")
print(f"Estimated Monthly Budget: ₦{estimated_monthly_budget:,.2f}")
print(f"Annual Spending Potential: ₦{annual_potential:,.2f}")
print(f"Customer Tier: {customer_tier}")
print(f"High Priority for Marketing: {high_priority}")

# Your task: Add one more calculation
# Calculate the customer's shopping frequency score (age factor * experience * smartphone bonus)
# - Age factor: 1.0 if age 25-45, 0.8 if younger/older
# - Experience: years_online_shopping / 5 (max 1.0)
# - Smartphone bonus: 1.2 if has smartphone, 1.0 if not

# Your code here:
age_factor = ______  # Complete this calculation
experience_factor = ______  # Complete this calculation
smartphone_bonus = ______  # Complete this calculation
shopping_frequency_score = ______  # Complete this calculation

print(f"Shopping Frequency Score: {shopping_frequency_score:.2f}")

# %% [markdown]
# ## Exercise 2: Lists and Business Collections (25 points)
#
# ### Task 2.1: Product Inventory

# %%
# Create lists for different product categories
electronics = ["iPhone 15", "Samsung Galaxy S24", "MacBook Pro", "AirPods Pro", "iPad Air"]
fashion = ["Nike Sneakers", "Adidas Tracksuit", "Zara Dress", "Ankara Fabric", "Leather Bag"]
home_garden = ["Sofa Set", "Dining Table", "Kitchen Blender", "Garden Tools", "Bed Frame"]

# Corresponding prices for each product (in same order)
electronics_prices = [1250000, 980000, 2500000, 350000, 750000]
fashion_prices = [85000, 45000, 25000, 15000, 120000]
home_garden_prices = [450000, 280000, 35000, 25000, 180000]

print("=== PRODUCT CATALOG ===")
print(f"Electronics ({len(electronics)} items):")
for i in range(len(electronics)):
    print(f"   {i+1}. {electronics[i]}: ₦{electronics_prices[i]:,}")

# Your task: Display fashion and home_garden categories in the same format
print(f"\nFashion ({len(fashion)} items):")
# Your code here

print(f"\nHome & Garden ({len(home_garden)} items):")
# Your code here

# Calculate category statistics
print("\n=== CATEGORY ANALYSIS ===")
print(f"Electronics - Total Value: ₦{sum(electronics_prices):,}, Average: ₦{sum(electronics_prices)/len(electronics_prices):,.2f}")

# Your task: Calculate the same statistics for fashion and home_garden
# Your code here

# %% [markdown]
# ### Task 2.2: Sales Analysis

# %%
# Monthly sales data for 6 months
months = ["July", "August", "September", "October", "November", "December"]
sales_figures = [2500000, 2750000, 2200000, 3100000, 2900000, 3800000]

# Find business insights
print("=== SALES PERFORMANCE ANALYSIS ===")

# Basic statistics
total_sales = sum(sales_figures)
average_monthly = total_sales / len(sales_figures)
best_month_sales = max(sales_figures)
worst_month_sales = min(sales_figures)

print(f"Total Sales (6 months): ₦{total_sales:,}")
print(f"Average Monthly Sales: ₦{average_monthly:,.2f}")
print(f"Best Month Sales: ₦{best_month_sales:,}")
print(f"Worst Month Sales: ₦{worst_month_sales:,}")

# Find which months had best/worst performance
best_month_index = sales_figures.index(best_month_sales)
worst_month_index = sales_figures.index(worst_month_sales)

print(f"\nBest performing month: {months[best_month_index]}")
print(f"Worst performing month: {months[worst_month_index]}")

# Your task: Calculate month-over-month growth rates
print("\n=== GROWTH ANALYSIS ===")
print("Month-over-Month Growth:")

# Calculate growth rate for each month compared to previous month
for i in range(1, len(sales_figures)):
    current_month = sales_figures[i]
    previous_month = sales_figures[i-1]
    growth_rate = ((current_month - previous_month) / previous_month) * 100
    
    # Your task: Complete this print statement
    print(f"   {months[i]}: {growth_rate:.1f}% vs {months[i-1]}")

# Your task: Identify months with positive vs negative growth
positive_growth_months = []
negative_growth_months = []

# Your code here to populate these lists

print(f"\nMonths with positive growth: {len(positive_growth_months)}")
print(f"Months with negative growth: {len(negative_growth_months)}")

# %% [markdown]
# ## Exercise 3: Dictionaries and Customer Management (25 points)
#
# ### Task 3.1: Customer Database

# %%
# Create detailed customer profiles using dictionaries
customer1 = {
    "name": "Adebayo Okonkwo",
    "email": "adebayo@email.com",
    "city": "Lagos",
    "age": 32,
    "total_orders": 15,
    "lifetime_value": 875000,
    "preferred_category": "Electronics",
    "is_vip": True,
    "last_order_date": "2024-01-15"
}

# Your task: Create customer2 and customer3 with different profiles
customer2 = {
    "name": "______",           # Fill in details
    "email": "______",
    "city": "______",           # Different Nigerian city
    "age": ______,
    "total_orders": ______,
    "lifetime_value": ______,
    "preferred_category": "______",  # Fashion or Home & Garden
    "is_vip": ______,           # Boolean
    "last_order_date": "______"
}

customer3 = {
    "name": "______",
    "email": "______",
    "city": "______",           # Third Nigerian city
    "age": ______,
    "total_orders": ______,
    "lifetime_value": ______,
    "preferred_category": "______",
    "is_vip": ______,
    "last_order_date": "______"
}

# Display customer profiles
customers = [customer1, customer2, customer3]

for i, customer in enumerate(customers, 1):
    avg_order_value = customer['lifetime_value'] / customer['total_orders']
    vip_status = "👑 VIP" if customer['is_vip'] else "Regular"
    
    print(f"\n=== CUSTOMER {i} ({vip_status}) ===")
    print(f"Name: {customer['name']}")
    print(f"Location: {customer['city']}")
    print(f"Age: {customer['age']}")
    print(f"Email: {customer['email']}")
    print(f"Total Orders: {customer['total_orders']}")
    print(f"Lifetime Value: ₦{customer['lifetime_value']:,}")
    print(f"Average Order: ₦{avg_order_value:,.2f}")
    print(f"Preferred Category: {customer['preferred_category']}")
    print(f"Last Order: {customer['last_order_date']}")

# %% [markdown]
# ### Task 3.2: Business Intelligence

# %%
# Analyze the customer database for business insights
print("=== CUSTOMER DATABASE ANALYSIS ===")

# Basic statistics
total_customers = len(customers)
total_orders = sum(customer['total_orders'] for customer in customers)
total_revenue = sum(customer['lifetime_value'] for customer in customers)
vip_customers = sum(1 for customer in customers if customer['is_vip'])

print(f"Total Customers: {total_customers}")
print(f"Total Orders: {total_orders}")
print(f"Total Revenue: ₦{total_revenue:,}")
print(f"VIP Customers: {vip_customers} ({(vip_customers/total_customers)*100:.1f}%)")
print(f"Average Revenue per Customer: ₦{total_revenue/total_customers:,.2f}")

# City analysis
cities = [customer['city'] for customer in customers]
unique_cities = list(set(cities))

print(f"\n=== GEOGRAPHIC DISTRIBUTION ===")
print(f"Cities represented: {len(unique_cities)}")
for city in unique_cities:
    city_customers = [c for c in customers if c['city'] == city]
    city_revenue = sum(c['lifetime_value'] for c in city_customers)
    print(f"   {city}: {len(city_customers)} customers, ₦{city_revenue:,} revenue")

# Your task: Category preference analysis
print(f"\n=== CATEGORY PREFERENCES ===")
categories = [customer['preferred_category'] for customer in customers]

# Count customers by preferred category
# Your code here to analyze category preferences

# Your task: Age group analysis
print(f"\n=== AGE GROUP ANALYSIS ===")
# Categorize customers by age: Young (18-30), Middle (31-45), Mature (46+)
# Your code here

# Your task: Find the most valuable customer
print(f"\n=== TOP CUSTOMER ANALYSIS ===")
# Find customer with highest lifetime value
# Find customer with most orders
# Find customer with highest average order value
# Your code here

# %% [markdown]
# ## Exercise 4: Working with DataFrames (30 points)
#
# ### Task 4.1: Create and Explore DataFrame

# %%
import pandas as pd
import numpy as np

# Create a comprehensive business dataset
business_data = {
    'order_id': ['ORD-1001', 'ORD-1002', 'ORD-1003', 'ORD-1004', 'ORD-1005', 
                 'ORD-1006', 'ORD-1007', 'ORD-1008', 'ORD-1009', 'ORD-1010'],
    'customer_name': ['Adebayo Okonkwo', 'Fatima Abdullahi', 'Chinedu Okoro', 'Amina Hassan', 'Yemi Adeyemi',
                      'Kemi Olatunji', 'Ahmed Bello', 'Grace Eze', 'Ibrahim Musa', 'Tolu Bakare'],
    'product_category': ['Electronics', 'Fashion', 'Electronics', 'Home & Garden', 'Books',
                        'Fashion', 'Electronics', 'Home & Garden', 'Fashion', 'Books'],
    'order_value': [125000, 45000, 890000, 78000, 12000, 
n                    67000, 340000, 156000, 23000, 8500],
    'city': ['Lagos', 'Abuja', 'Port Harcourt', 'Kano', 'Ibadan',
             'Lagos', 'Abuja', 'Kano', 'Lagos', 'Ibadan'],
    'order_date': ['2024-01-15', '2024-01-16', '2024-01-17', '2024-01-18', '2024-01-19',
                   '2024-01-20', '2024-01-21', '2024-01-22', '2024-01-23', '2024-01-24'],
    'payment_method': ['Card', 'Transfer', 'Card', 'Cash', 'Transfer',
                       'Card', 'Card', 'Cash', 'Transfer', 'Transfer'],
    'is_vip': [True, False, True, False, False, False, True, False, False, False]
}

# Create DataFrame
df = pd.DataFrame(business_data)

print("=== DATASET CREATED ===")
print(f"Shape: {df.shape}")
print("\nFirst 5 rows:")
print(df.head())

print("\n=== DATASET INFO ===")
df.info()

print("\n=== BASIC STATISTICS ===")
print(df.describe())

# %% [markdown]
# ### Task 4.2: Data Analysis Questions
#
# Answer the following business questions using pandas operations:

# %%
print("=== BUSINESS ANALYSIS QUESTIONS ===")

# Question 1: What's the total revenue by city?
print("\n1. REVENUE BY CITY:")
city_revenue = df.groupby('city')['order_value'].sum().sort_values(ascending=False)
print(city_revenue)

# Question 2: Which payment method is most popular?
print("\n2. PAYMENT METHOD POPULARITY:")
# Your code here

# Question 3: What's the average order value by category?
print("\n3. AVERAGE ORDER VALUE BY CATEGORY:")
# Your code here

# Question 4: How many VIP vs regular customers?
print("\n4. VIP VS REGULAR CUSTOMERS:")
# Your code here

# Question 5: What's the date range of orders?
print("\n5. ORDER DATE RANGE:")
# Your code here

# Question 6: Top 3 highest value orders
print("\n6. TOP 3 HIGHEST VALUE ORDERS:")
top_orders = df.nlargest(3, 'order_value')[['customer_name', 'product_category', 'order_value', 'city']]
print(top_orders)

# Question 7: Electronics orders only
print("\n7. ELECTRONICS ORDERS ANALYSIS:")
electronics_df = df[df['product_category'] == 'Electronics']
print(f"Electronics orders: {len(electronics_df)}")
print(f"Electronics revenue: ₦{electronics_df['order_value'].sum():,}")
print(f"Average electronics order: ₦{electronics_df['order_value'].mean():,.2f}")

# Question 8: Your turn - create an interesting analysis
print("\n8. YOUR CUSTOM ANALYSIS:")
# Create your own analysis question and answer it
# Examples: Lagos VIP customers, Cash payment analysis, etc.
# Your code here

# %% [markdown]
# ### Task 4.3: Business Insights Report

# %%
# Create a comprehensive business report
print("=== COMPREHENSIVE BUSINESS REPORT ===")
print(f"Analysis Date: {pd.Timestamp.now().strftime('%Y-%m-%d')}")
print(f"Data Period: {df['order_date'].min()} to {df['order_date'].max()}")

# Executive Summary
total_revenue = df['order_value'].sum()
total_orders = len(df)
avg_order_value = df['order_value'].mean()
unique_customers = df['customer_name'].nunique()

print(f"\n=== EXECUTIVE SUMMARY ===")
print(f"💰 Total Revenue: ₦{total_revenue:,}")
print(f"📦 Total Orders: {total_orders}")
print(f"📊 Average Order Value: ₦{avg_order_value:,.2f}")
print(f"👥 Unique Customers: {unique_customers}")
print(f"📈 Revenue per Customer: ₦{total_revenue/unique_customers:,.2f}")

# Category Performance
print(f"\n=== CATEGORY PERFORMANCE ===")
category_stats = df.groupby('product_category').agg({
    'order_value': ['count', 'sum', 'mean']
}).round(2)
category_stats.columns = ['Orders', 'Revenue', 'Avg_Order']
category_stats = category_stats.sort_values('Revenue', ascending=False)

for category, row in category_stats.iterrows():
    print(f"   {category}:")
    print(f"      Orders: {row['Orders']}")
    print(f"      Revenue: ₦{row['Revenue']:,.0f}")
    print(f"      Avg Order: ₦{row['Avg_Order']:,.2f}")

# Your task: Add more sections to the report
print(f"\n=== GEOGRAPHIC ANALYSIS ===")
# Your code here

print(f"\n=== CUSTOMER INSIGHTS ===")
# Your code here

print(f"\n=== RECOMMENDATIONS ===")
# Based on your analysis, what are your business recommendations?
# Your written recommendations here

# %% [markdown]
# ## Reflection Questions
#
# **Instructions**: Answer these questions based on your experience with today's exercises.
#
# ### 1. Excel to Python Connections
# **Question**: Which Python concept was most similar to something you already knew from Excel? Why?
#
# **Your Answer**:
# _Write your response here..._
#
# ### 2. Biggest Challenge
# **Question**: What was the most challenging part of today's exercises? How did you overcome it?
#
# **Your Answer**:
# _Write your response here..._
#
# ### 3. Most Useful Skill
# **Question**: Which skill from today (variables, lists, dictionaries, or DataFrames) do you think will be most useful for business analysis? Why?
#
# **Your Answer**:
# _Write your response here..._
#
# ### 4. Business Applications
# **Question**: Think about your current job or business interests. How could you apply what you learned today to solve a real problem?
#
# **Your Answer**:
# _Write your response here..._
#
# ### 5. Preparation for SQL
# **Question**: Tomorrow we'll learn SQL (database queries) to analyze the same type of data. What similarities do you expect between Python and SQL?
#
# **Your Answer**:
# _Write your response here..._
#
# ### 6. Confidence Level
# **Question**: On a scale of 1-10, how confident do you feel about using Python for data analysis after today? What would help you feel more confident?
#
# **Your Answer**:
# _Write your response here..._

# %% [markdown]
# ## Submission Checklist
#
# Before submitting, make sure you have:
#
# - [ ] ✅ Completed all variable creation tasks in Exercise 1
# - [ ] ✅ Finished business calculations with proper formatting
# - [ ] ✅ Created and analyzed lists in Exercise 2
# - [ ] ✅ Built customer dictionaries with complete profiles
# - [ ] ✅ Successfully created and analyzed DataFrames
# - [ ] ✅ Answered all business analysis questions
# - [ ] ✅ Completed the reflection questions
# - [ ] ✅ Code runs without errors
# - [ ] ✅ Results make business sense
#
# **Grading Criteria**:
# - **Code Functionality** (40%): Does your code run without errors?
# - **Business Logic** (30%): Are your calculations and analysis logical?
# - **Completeness** (20%): Did you complete all required tasks?
# - **Insights** (10%): Did you provide thoughtful analysis and reflections?
#
# ---
#
# **Great job completing your first Python programming assignment! You're ready for tomorrow's SQL session where you'll learn to do similar analysis with database queries.**
